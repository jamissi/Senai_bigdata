# %% [markdown]
# <a href="https://colab.research.google.com/github/jamissi/Senai_bigdata/blob/main/Pandas_Senai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**01/07/2023 - Pandas** 🐼
#
# ---

# %% [markdown]
# *   *DataSus*
# *   *Kaggle*

# %%
import pandas as pd

# %%
#@title Importando o arquivo
df = pd.read_csv("/content/drive/MyDrive/big_data_senai/moradias_SP.csv", sep= ",")

# %%
#@title Mostrando primeiras linhas do DataFrame, por padrão mostrará as cincos 1º
df.head(10)
# Out:
#                   address           district  area  bedrooms  garage  \
# 0              Rua Herval         Belenzinho    21         1       0
# 1      Avenida São Miguel       Vila Marieta    15         1       1
# 2        Rua Oscar Freire          Pinheiros    18         1       0
# 3        Rua Júlio Sayago            Vila Ré    56         2       2
# 4      Rua Barata Ribeiro         Bela Vista    19         1       0
# 5      Rua Domingos Paiva               Brás    50         2       1
# 6          Rua Guararapes  Brooklin Paulista    72         2       1
# 7   Avenida Cásper Líbero             Centro    26         1       0
# 8  Rua José Peres Campelo            Piqueri    32         2       0
# 9           Rua Guaperuvu    Vila Aricanduva    36         1       0
#
#                  type  rent  total
# 0     Studio e kitnet  2400   2939
# 1     Studio e kitnet  1030   1345
# 2         Apartamento  4000   4661
# 3  Casa em condomínio  1750   1954
# ...

# %%
#@title Mostrando as últimas linhas do DataFrame
df.tail(15)
# Out:
#                                        address  \
# 11642    Avenida Dona Helena Pereira de Moraes
# 11643  Avenida Doutor Alberto de Oliveira Lima
# 11644                    Rua Fernandes Moreira
# 11645                        Avenida João Dias
# 11646             Rua Domingos Antonio Ciccone
# 11647          Rua Professor Alexandre Correia
# 11648               Rua Vespasiano de Oliveira
# 11649           Rua Leonardo Cerveira Varandas
# 11650                           Rua Ambrizette
# 11651                                 São José
# 11652                  Avenida Adolfo Pinheiro
# 11653          Rua Professor Alexandre Correia
# 11654                         Rua Abílio Borin
# 11655                        Rua Forte William
# 11656                      Rua Alexandre Dumas
#
#                                district  area  bedrooms  garage  \
# 11642                 Parque do Morumbi   220         2       0
# 11643                   Vila Tramontano   240         6       3
# ...

# %%
#@title Análise do DataFrame
df.shape #mostrará quantas linhas e colunas em uma tupla.
# Out:
# (11657, 8)

# %%
df.info() #visualizará os tipos de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11657 entries, 0 to 11656
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   address   11657 non-null  object
#  1   district  11657 non-null  object
#  2   area      11657 non-null  int64
#  3   bedrooms  11657 non-null  int64
#  4   garage    11657 non-null  int64
#  5   type      11657 non-null  object
#  6   rent      11657 non-null  int64
#  7   total     11657 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 728.7+ KB

# %%
df["district"].head() #mostrará todos os bairros que há no df
# Out:
# 0      Belenzinho
# 1    Vila Marieta
# 2       Pinheiros
# 3         Vila Ré
# 4      Bela Vista
# Name: district, dtype: object

# %%
df[["district"]].head() #mostrará todos os bairros que há no df no estilo pandas
# Out:
#        district
# 0    Belenzinho
# 1  Vila Marieta
# 2     Pinheiros
# 3       Vila Ré
# 4    Bela Vista

# %%
df[["district", "rent"]].head()
# Out:
#        district  rent
# 0    Belenzinho  2400
# 1  Vila Marieta  1030
# 2     Pinheiros  4000
# 3       Vila Ré  1750
# 4    Bela Vista  4000

# %%
df.type.head(50).unique() #filtrará os tipos unicamente de moradia
# Out:
# array(['Studio e kitnet', 'Apartamento', 'Casa em condomínio', 'Casa'],
#       dtype=object)

# %%
#@title Realizando alguns filtro no DataFrame
a1 = df["type"] == 'Studio e kitnet'
a2 = df["district"] == 'Brás'
df[a1 & a2]

# %%
#@title Usando função query
df.query("district == 'Brás' and type == 'Studio e kitnet'").head()
# Out:
#                        address district  area  bedrooms  garage  \
# 74           Rua Coronel Mursa     Brás    19         1       0
# 603   Rua Visconde de Parnaíba     Brás    26         1       0
# 1125       Rua Sampaio Moreira     Brás    20         1       0
# 1175         Rua Caetano Pinto     Brás    40         1       0
# 1407          Rua do Gasômetro     Brás    60         1       0
#
#                  type  rent  total
# 74    Studio e kitnet  1700   2016
# 603   Studio e kitnet  1350   1722
# 1125  Studio e kitnet  1500   1558
# 1175  Studio e kitnet  2000   2437
# 1407  Studio e kitnet   995   1408

# %%
df.query("district == 'Vila Monte Alegre' and type == 'Casa'").head(100)
# Out:
#                 address           district  area  bedrooms  garage  type  \
# 10080  Rua Major Freire  Vila Monte Alegre   320         4       4  Casa
#
#        rent  total
# 10080  6000   7782

# %%
df.query("bedrooms > 5").head(100)
# Out:
#                                        address                       district  \
# 6711         Rua Antônio Pinto do Rêgo Freitas  Jardim Boa Vista (zona Oeste)
# 8457                          Avenida São Luís                      República
# 8651                      Rua Vieira de Morais                     Campo Belo
# 8714       Rua Doutor Abelardo Vergueiro César                Vila Alexandria
# 8801                    Rua Doutor Renan Basto                   Vila Guarani
# 8880                      Rua Francisco Polito                  Vila Prudente
# 8959                    Avenida Paes de Barros                          Mooca
# 9121                      Rua David Ben Gurion             Jardim Monte Kemel
# 9123                         Rua Franco Alfano                  Jardim Vazani
# 9607                         Rua Félix Guilhem                  Lapa de Baixo
# 9700           Rua Beranizia de Paula Oliveira             Sítio Morro Grande
# ...

# %%
#@title Análise exploratória geral (numérica)
df.describe()
# Out:
#                area      bedrooms        garage          rent         total
# count  11657.000000  11657.000000  11657.000000  11657.000000  11657.000000
# mean      84.655658      1.966286      1.060393   3250.814789   4080.030625
# std       74.020536      0.931313      1.132349   2650.711557   3352.480274
# min        0.000000      0.000000      0.000000    500.000000    509.000000
# 25%       40.000000      1.000000      0.000000   1590.000000   1996.000000
# 50%       60.000000      2.000000      1.000000   2415.000000   3057.000000
# 75%       96.000000      3.000000      2.000000   3800.000000   4774.000000
# max      580.000000      6.000000      6.000000  25000.000000  28700.000000

# %%
df.query("area == 0").head()
# Out:
#                     address                district  area  bedrooms  garage  \
# 2983           Rua Relíquia  Jardim das Laranjeiras     0         2       1
# 7085  Rua Edmundo de Amicis                 Morumbi     0         3       2
#
#              type  rent  total
# 2983  Apartamento  1600   2569
# 7085         Casa  3200   3351

# %%
#@title Analisando apenas uma coluna com a função describe()
df[["rent"]].describe()
# Out:
#                rent
# count  11657.000000
# mean    3250.814789
# std     2650.711557
# min      500.000000
# 25%     1590.000000
# 50%     2415.000000
# 75%     3800.000000
# max    25000.000000

# %%
#@title Média de aluguel por tipo de moradia
#df.groupby("tipo")[["total"]].mean().sort_values("total", ascending=False)
# Out:
#                           total
# type
# Casa em condomínio  4576.232365
# Apartamento         4435.428413
# Casa                3824.244280
# Studio e kitnet     2668.280232

# %%
df.query("rent == 3800 and type == 'Casa'").head(200)
# Out:
#                                    address                      district  \
# 965                       Rua Carlos Petit                  Vila Mariana
# 1020                       Rua dos Macaxás                     Vila Nair
# 1452           Rua Domiciano Leite Ribeiro       Vila Guarani (zona Sul)
# 2192                    Rua Benjamin Costa              Jardim Aeroporto
# 3316                           Rua Itararé                   Vila Alzira
# 5387                           Rua Alsácia              Jardim Aeroporto
# 6196                        Rua Califórnia                Cidade Monções
# 7207            Rua Porfírio do Nascimento                   Vila Romano
# 7214                  Rua François Carlier  Vila Santa Teresa (zona Sul)
# 7732                          Rua Sepetiba                     Siciliano
# 7808       Rua Coronel Virgilio dos Santos                       Jaguará
# 7911           Rua General Syzeno Sarmento              Jardim Esmeralda
# ...

# %%
#@title Renomeando Colunas:
df.rename(columns={"address":"endereco"}, inplace=True)

# %%
df.rename(columns={
    "district":"bairro",
    "bedrooms":"quartos",
    "garage":"vagas_de_garagem",
    "type":"tipo",
    "rent":"aluguel"
    }, inplace=True)

# %%
grafico = df.groupby("tipo")[["total"]].mean().sort_values("total", ascending=False)

# %%
grafico.head()
# Out:
#                           total
# tipo
# Casa em condomínio  4576.232365
# Apartamento         4435.428413
# Casa                3824.244280
# Studio e kitnet     2668.280232

# %%
grafico.plot(
    kind="bar",
    xlabel="Total Mensal",
    ylabel="Tipo Imovel",
    color = "#D8BFD8"
)
# Out:
# <Axes: xlabel='Total Mensal', ylabel='Tipo Imovel'>

# %%
#@title Adicionando nova coluna no DataFrame
df["cond_iptu"] = df["total"] - df["aluguel"]

# %%
df.head(2000)
# Out:
#                    endereco                            bairro  area  quartos  \
# 0                Rua Herval                        Belenzinho    21        1
# 1        Avenida São Miguel                      Vila Marieta    15        1
# 2          Rua Oscar Freire                         Pinheiros    18        1
# 3          Rua Júlio Sayago                           Vila Ré    56        2
# 4        Rua Barata Ribeiro                        Bela Vista    19        1
# ...                     ...                               ...   ...      ...
# 1995    Rua Alexandre Dumas  Chácara Santo Antônio (zona Sul)    45        2
# 1996        Rua Silva Teles                              Brás    59        2
# 1997            Rua Genebra                        Bela Vista    25        1
# 1998  Rua Monsenhor Andrade                              Brás    80        2
# 1999  Avenida Gaivota Preta                    Jardim Valéria    50        2
#
# ...

# %%
#@title Alterando ordem de colunas "na mão"
df["total2"] = df["total"]

# %%
#@title Excluindo uma coluna
df.drop("total", axis=1, inplace=True)

# %%
df.rename(columns={"total2": "total"}, inplace=True)

# %%
df.head()
# Out:
#              endereco        bairro  area  quartos  vagas_de_garagem  \
# 0          Rua Herval    Belenzinho    21        1                 0
# 1  Avenida São Miguel  Vila Marieta    15        1                 1
# 2    Rua Oscar Freire     Pinheiros    18        1                 0
# 3    Rua Júlio Sayago       Vila Ré    56        2                 2
# 4  Rua Barata Ribeiro    Bela Vista    19        1                 0
#
#                  tipo  aluguel  cond_iptu  total
# 0     Studio e kitnet     2400        539   2939
# 1     Studio e kitnet     1030        315   1345
# 2         Apartamento     4000        661   4661
# 3  Casa em condomínio     1750        204   1954
# 4     Studio e kitnet     4000        654   4654

# %%
#@title Verificando existência de dados nulos no DataFrame
df[["total"]].isnull().sum()
# Out:
# total    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# endereco            0
# bairro              0
# area                0
# quartos             0
# vagas_de_garagem    0
# tipo                0
# aluguel             0
# cond_iptu           0
# total               0
# dtype: int64

# %%
#@title Substituindo valores nulos por 0 em todas as colunas do DataFrame
df = df.fillna(0)

# %% [markdown]
# ###**Montando Gráfico de dispersão com MatPlotLib** 📊

# %%
import matplotlib.pyplot as plt

# %%
#O gráfico de dispersão analisa a relação entre duas variáveis
fig = plt.figure(figsize=(8,6))
eixo = fig.add_axes([0,0,1,1])
eixo.set_title("Total por tipo de moradia")
eixo.set_xlabel("Total Mensal")
eixo.set_ylabel("Tipo Moradia")
eixo.legend(["Total Mensal"], loc="upper right")
eixo.scatter(df["total"], df["tipo"], color="red")

# %%
fig = plt.figure(figsize=(8,6))
eixo = fig.add_axes([0,0,1,1])
eixo.set_title("Relação Área x Aluguel")
eixo.set_xlabel("Total Mensal")
eixo.set_ylabel("Área")
eixo.legend(["Total Mensal"], loc="upper right")
eixo.scatter(df["total"], df["area"], color="orange", marker="_")
